# %% [markdown]
# # Sentiment and data mining

# %%
import os
import numpy as np

# Load the dataset
train_texts = []
train_labels = []
test_texts = []
test_labels = []
for dset in ['train', 'test']:
    for cat in ['pos', 'neg']:
        dset_path = os.path.join('data', dset, cat)
        for fname in sorted(os.listdir(dset_path)):
            if fname.endswith('.txt'):
                with open(os.path.join(dset_path, fname)) as f:
                    if dset == 'train': train_texts.append(f.read())
                    else: test_texts.append(f.read())
                label = 0 if cat == 'neg' else 1
                if dset == 'train': train_labels.append(label)
                else: test_labels.append(label)

# Converting to np.array
train_texts = np.array(train_texts)
train_labels = np.array(train_labels)
test_texts = np.array(test_texts)
test_labels = np.array(test_labels)

# %%
import pandas as pd
train_folder = 'data/train/'
labels = {'pos': 1, 'neg': 0}

train_data = pd.DataFrame()
   
for l in ('pos', 'neg'):
    path = os.path.join(train_folder, l)
    for file in os.listdir (path) :
        with open(os.path.join(path, file),'r', encoding='utf-8') as infile:
            txt = infile.read()
        train_data = train_data.append([[txt, labels[l]]],ignore_index=True)
train_data.columns = ['review', 'sentiment']
train_data.to_csv('data/train_data.tsv', sep='\t', encoding='utf-8')


test_folder = 'data/test/'
test_data = pd.DataFrame()  
for l in ('pos', 'neg'):
    path = os.path.join(test_folder, l)
    for file in os.listdir (path) :
        with open(os.path.join(path, file),'r', encoding='utf-8') as infile:
            txt = infile.read()
        test_data = test_data.append([[txt, labels[l]]],ignore_index=True)
test_data.columns =  ['review', 'sentiment']
test_data.to_csv('data/test_data.tsv', sep='\t', encoding='utf-8')

# %%
print(len(train_texts))
print(len(train_labels))
print(len(test_texts))
print(len(test_labels))
train_data.head()
test_data.head()
# Out:
# 25000
# 25000
# 25000
# 25000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-dcb7d4a42865> in <module>
#       4 print(len(test_labels))
#       5 train_data.head()
# ----> 6 test_data.head()
#
# NameError: name 'test_data' is not defined

# %%
import re

REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

def preprocess_reviews(reviews):
    reviews = [REPLACE_NO_SPACE.sub("", line.lower()) for line in reviews]
    reviews = [REPLACE_WITH_SPACE.sub(" ", line) for line in reviews]
    
    return reviews


train_data['review'] = train_data['review'].apply(preprocess_reviews)
test_data['review'] = test_data['review'].apply(preprocess_reviews)
train_texts_clean = preprocess_reviews(train_texts)
print(train_data.head())
print(test_data.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-c8c5e86d7742> in <module>
#      18
#      19
# ---> 20 train_texts_clean = reviewWords(train_texts)
#      21 print(train_texts_clean[100])
#      22 print(train_labels[100])
#
# <ipython-input-23-c8c5e86d7742> in reviewWords(review)
#       7
#       8 def reviewWords(review):
# ----> 9     data_train_Exclude_tags = re.sub(r'<[^<>]+>', " ", review)      # Excluding the html tags
#      10     data_train_num = re.sub(r'[0-9]+', 'number', data_train_Exclude_tags)  # Converting numbers to "NUMBER"
#      11     data_train_lower = data_train_num.lower()              # Converting to lower case.
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: cannot use a string pattern on a bytes-like object

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(analyzer='word', ngram_range=(2,2), min_df = 0)

print(cv.fit_transform(train_texts))
# Out:
#   (0, 665027)	1
#   (0, 1217275)	1
#   (0, 951807)	1
#   (0, 1380846)	1
#   (0, 449168)	1
#   (0, 439118)	1
#   (0, 654713)	1
#   (0, 1257771)	1
#   (0, 37755)	1
#   (0, 827448)	1
#   (0, 876476)	1
#   (0, 31798)	1
#   (0, 765459)	1
#   (0, 1217881)	1
#   (0, 424171)	1
#   (0, 579229)	1
#   (0, 1278236)	1
#   (0, 1373879)	1
#   (0, 1174186)	1
#   (0, 1202947)	1
#   (0, 1435609)	1
#   (0, 882238)	1
#   (0, 895600)	1
#   (0, 1054146)	1
#   (0, 1283916)	1
#   :	:
#   (24999, 108710)	1
#   (24999, 1251683)	1
#   (24999, 854560)	1
#   (24999, 525249)	1
#   (24999, 657212)	1
#   (24999, 613689)	1
#   (24999, 1283996)	1
#   (24999, 880745)	1
#   (24999, 1358691)	1
#   (24999, 1432091)	1
#   (24999, 242811)	1
#   (24999, 728745)	1
#   (24999, 118027)	1
#   (24999, 1216819)	1
#   (24999, 63226)	1
#   (24999, 667757)	1
#   (24999, 1260970)	2
#   (24999, 415214)	1
#   (24999, 1281969)	1
#   (24999, 613840)	1
#   (24999, 188196)	1
#   (24999, 895600)	1
#   (24999, 1241567)	1
#   (24999, 880731)	1
#   (24999, 627398)	1

# %%
analyze = cv.build_analyzer()
# Out:
# ['futz is',
#  'is the',
#  'the only',
#  'only show',
#  'show preserved',
#  'preserved from',
#  'from the',
#  'the experimental',
#  'experimental theatre',
#  'theatre movement',
#  'movement in',
#  'in new',
#  'new york',
#  'york in',
#  'in the',
#  'the 1960s',
#  '1960s the',
#  'the origins',
#  'origins of',
#  'of off',
#  'off off',
#  'off broadway',
#  'broadway though',
#  'though it',
#  'it not',
#  'not for',
#  'for everyone',
#  'everyone it',
#  'it is',
#  'is genuinely',
#  'genuinely brilliant',
#  'brilliant darkly',
#  'darkly funny',
#  'funny even',
#  'even more',
#  'more often',
#  'often deeply',
#  'deeply disturbing',
#  'disturbing tale',
#  'tale about',
#  'about love',
#  'love sex',
#  'sex personal',
#  'personal liberty',
#  'liberty and',
#  'and revenge',
#  'revenge serious',
#  'serious morality',
#  'morality tale',
#  'tale even',
#  'even more',
#  'more relevant',
#  'relevant now',
#  'now in',
#  'in time',
#  'time when',
#  'when congress',
#  'congress wants',
#  'wants to',
#  'to outlaw',
#  'outlaw gay',
#  'gay marriage',
#  'marriage by',
#  'by trashing',
#  'trashing our',
#  'our constitution',
#  'constitution the',
#  'the story',
#  'story is',
#  'is not',
#  'not about',
#  'about being',
#  'being gay',
#  'gay though',
#  'though it',
#  'it about',
#  'about love',
#  'love and',
#  'and sex',
#  'sex that',
#  'that don',
#  'don conform',
#  'conform to',
#  'to social',
#  'social norms',
#  'norms and',
#  'and therefore',
#  'therefore must',
#  'must be',
#  'be removed',
#  'removed through',
#  'through violence',
#  'violence and',
#  'and hate',
#  'hate on',
#  'on the',
#  'the surface',
#  'surface it',
#  'it tells',
#  'tells the',
#  'the story',
#  'story of',
#  'of man',
#  'man who',
#  'who falls',
#  'falls in',
#  'in love',
#  'love with',
#  'with pig',
#  'pig but',
#  'but like',
#  'like any',
#  'any great',
#  'great fable',
#  'fable it',
#  'it not',
#  'not really',
#  'really about',
#  'about animals',
#  'animals it',
#  'it about',
#  'about something',
#  'something bigger',
#  'bigger stifling',
#  'stifling conformity',
#  'conformity in',
#  'in america',
#  'america br',
#  'br br',
#  'br the',
#  'the stage',
#  'stage version',
#  'version won',
#  'won international',
#  'international acclaim',
#  'acclaim in',
#  'in its',
#  'its original',
#  'original production',
#  'production it',
#  'it toured',
#  'toured the',
#  'the and',
#  'and europe',
#  'europe and',
#  'and with',
#  'with others',
#  'others of',
#  'of its',
#  'its kind',
#  'kind influenced',
#  'influenced almost',
#  'almost all',
#  'all theatre',
#  'theatre that',
#  'that came',
#  'came after',
#  'after it',
#  'it luckily',
#  'luckily we',
#  'we have',
#  'have preserved',
#  'preserved here',
#  'here the',
#  'the show',
#  'show pretty',
#  'pretty much',
#  'much as',
#  'as it',
#  'it was',
#  'was originally',
#  'originally conceived',
#  'conceived with',
#  'with the',
#  'the original',
#  'original cast',
#  'cast and',
#  'and original',
#  'original director',
#  'director tom',
#  'tom horgan',
#  'horgan who',
#  'who also',
#  'also directed',
#  'directed hair',
#  'hair and',
#  'and jesus',
#  'jesus christ',
#  'christ superstar',
#  'superstar on',
#  'on broadway',
#  'broadway br',
#  'br br',
#  'br this',
#  'this is',
#  'is not',
#  'not mainstream',
#  'mainstream easy',
#  'easy to',
#  'to take',
#  'take studio',
#  'studio film',
#  'film this',
#  'this is',
#  'is an',
#  'an aggressive',
#  'aggressive unsettling',
#  'unsettling glorious',
#  'glorious deeply',
#  'deeply emotional',
#  'emotional wildly',
#  'wildly imaginative',
#  'imaginative piece',
#  'piece of',
#  'of storytelling',
#  'storytelling that',
#  'that you',
#  'you ll',
#  'll never',
#  'never forget',
#  'forget and',
#  'and it',
#  'it just',
#  'just might',
#  'might change',
#  'change the',
#  'the way',
#  'way you',
#  'you see',
#  'see the',
#  'the world']
